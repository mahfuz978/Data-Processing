# %% [markdown]
# <a href="https://colab.research.google.com/github/mahfuz978/TECH-I.S.---DATA-PROCESSING/blob/main/Mahfuzur_Rahman_Step_1_4e_Pandas_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
arr1 = np.random.rand(10,4)
arr1
# Out:
# array([[0.07520412, 0.62298721, 0.460662  , 0.61532561],
#        [0.44690141, 0.41824983, 0.26905889, 0.128318  ],
#        [0.41321263, 0.46915677, 0.68970768, 0.66036191],
#        [0.38213773, 0.52318594, 0.0751168 , 0.74185183],
#        [0.28092255, 0.31314579, 0.66967967, 0.18571979],
#        [0.91988637, 0.64251107, 0.53713766, 0.64828987],
#        [0.47043533, 0.15320215, 0.61325887, 0.17542098],
#        [0.73729335, 0.0380748 , 0.19223575, 0.06984181],
#        [0.15969558, 0.62589792, 0.12264179, 0.58850039],
#        [0.10256288, 0.20557992, 0.63851068, 0.87818014]])

# %%
df = pd.DataFrame(arr1, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.075204  0.622987  0.460662  0.615326
# 1  0.446901  0.418250  0.269059  0.128318
# 2  0.413213  0.469157  0.689708  0.660362
# 3  0.382138  0.523186  0.075117  0.741852
# 4  0.280923  0.313146  0.669680  0.185720
# 5  0.919886  0.642511  0.537138  0.648290
# 6  0.470435  0.153202  0.613259  0.175421
# 7  0.737293  0.038075  0.192236  0.069842
# 8  0.159696  0.625898  0.122642  0.588500
# 9  0.102563  0.205580  0.638511  0.878180

# %%
df.plot.bar(figsize = (8,5));

# %%
df.plot.bar(stacked = True, figsize = (8,5));

# %%
df.plot.barh(figsize = (8,5), stacked = True);

# %%
# set the color palette
sns.set_palette('magma')

# %%
df.plot.bar(figsize = (8,5), stacked = True);

# %%
sns.set_palette('muted')
df.plot.area(figsize = (10,7));

# %%
df.plot.area(figsize  = (10,7),stacked = False);

# %%
df.diff()
# Out:
#           a         b         c         d
# 0       NaN       NaN       NaN       NaN
# 1  0.371697 -0.204737 -0.191603 -0.487008
# 2 -0.033689  0.050907  0.420649  0.532044
# 3 -0.031075  0.054029 -0.614591  0.081490
# 4 -0.101215 -0.210040  0.594563 -0.556132
# 5  0.638964  0.329365 -0.132542  0.462570
# 6 -0.449451 -0.489309  0.076121 -0.472869
# 7  0.266858 -0.115127 -0.421023 -0.105579
# 8 -0.577598  0.587823 -0.069594  0.518659
# 9 -0.057133 -0.420318  0.515869  0.289680

# %%
df.diff().plot.box(vert = False,
                   color={'medians':'lightblue',
                            'boxes':'blue',
                            'caps':'darkblue',});

# %%
arr = np.random.rand(100,1)

# %%
arr[:5]
# Out:
# array([[0.32019732],
#        [0.44930658],
#        [0.99794784],
#        [0.55921795],
#        [0.42038154]])

# %%
df = pd.DataFrame(arr, columns=["val"]).reset_index()
df
# Out:
#     index       val
# 0       0  0.320197
# 1       1  0.449307
# 2       2  0.997948
# 3       3  0.559218
# 4       4  0.420382
# ..    ...       ...
# 95     95  0.185036
# 96     96  0.086904
# 97     97  0.420684
# 98     98  0.074894
# 99     99  0.229687
#
# [100 rows x 2 columns]

# %%
df['val'].plot(figsize = (10,7));

# %%
df.val.rolling(10).mean().plot(figsize = (10,7));

# %%
df.val.plot.kde();

# %%
df.plot.scatter(x='index',y='val', 
                  c='C', #color of data points
                  s=df.val*200,figsize=(10,7));
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py:1016: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   **self.kwds,

# %%
df.plot.hexbin(x = 'index', y= 'val', gridsize = 20, figsize = (10,7));

# %%
arr = np.random.rand(5,2)

# %%
df = pd.DataFrame(arr,index=list("ABCDE"), columns=list("XY"))

# %%
df
# Out:
#           X         Y
# A  0.902827  0.136312
# B  0.518884  0.305226
# C  0.153536  0.467023
# D  0.976489  0.141257
# E  0.488561  0.493738

# %%
df.plot.pie(subplots = True, figsize = (10,7));

# %%
arr = np.random.rand(100, 4)
df = pd.DataFrame(arr, columns=list('ABCD'))
df.head()
# Out:
#           A         B         C         D
# 0  0.116270  0.715017  0.198312  0.299299
# 1  0.726146  0.600226  0.322710  0.593982
# 2  0.240603  0.440657  0.535487  0.538290
# 3  0.321191  0.754699  0.662581  0.773415
# 4  0.373592  0.420869  0.919673  0.062707

# %%
df.plot(subplots = True, figsize = (10,7));

# %%
df.plot(subplots = True, layout = (2,2), figsize = (10,7));
